# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from gurobipy import Model, GRB, quicksum, LinExpr
import eat
import graphviz
from IPython.display import Image, display
import pickle
import os
from scipy.stats import ks_2samp


N1=list(range(0,100))
N2=list(range(100, 150))
R1, R2=[0], [1,2]
N1_bar=list(range(0,150))
N2_bar=list(range(0,100))
m, q, n = 3, 3, 150


def TreeDMUs(tree):
    res = {}
    for node in tree.tree:
        if node.get("SL") == -1:
            res[node["id"]] = {"dmus":node["index"],
                               'a': node['a'],
                               'b': node['b'],
                               'y': node['y']}
    return res

def stats(df, col):
    avg_eff = df[col].mean()
    min_eff = df[col].min()
    max_eff = df[col].max()
    std_dev_eff = df[col].std()
    num_eff = (df[col]==1).sum()
    num_considered = len(df)

    result = {
        'avg': avg_eff,
        'min': min_eff,
        'max': max_eff,
        'std_dev': std_dev_eff,
        'num_eff': num_eff,
        'num_considered': num_considered
    }
    return result

os.makedirs("iterations", exist_ok=True)

for i in range(3):
        iter_dir = f'iterations/iter_{i}'
        tree_dir = os.path.join(iter_dir, 'tree')
        os.makedirs(iter_dir, exist_ok=True)
        os.makedirs(tree_dir, exist_ok=True)
        
        #######################
        Xa = np.random.choice(np.concatenate([np.arange(-50, 0), np.arange(1, 51)]), size=(100, 3))
        Xb = np.random.choice(np.concatenate([np.arange(-50, 0), np.arange(1, 51)]), size=(50, 3))

        Ya = np.random.choice(np.concatenate([np.arange(-50, 0), np.arange(1, 51)]), size=(100, 3))
        Yb = np.random.choice(np.concatenate([np.arange(-50, 0), np.arange(1, 51)]), size=(50, 1))

        dataA = np.concatenate([Xa, Ya], axis=1)
        dataB = np.concatenate([Xb, Yb], axis=1)

        columns_A = ['x1', 'x2', 'x3', 'y1', 'y2', 'y3']
        columns_B = ['x1', 'x2', 'x3', 'y1']

        dfA = pd.DataFrame(dataA, columns=columns_A)
        dfB = pd.DataFrame(dataB, columns=columns_B)

        dfA['DMU'] = np.arange(dfA.shape[0])
        dfB['DMU'] = np.arange(dfB.shape[0])
        #######################


        #######################
        tree1 = eat.EAT(dfA, ['x1', 'x2', 'x3'], ['y1', 'y2', 'y3'], numStop=10, fold=5)
        tree2 = eat.EAT(dfB, ['x1', 'x2', 'x3'], ['y1'], numStop=10, fold=5)

        treeleaf1 = TreeDMUs(tree1)
        treeleaf2 = TreeDMUs(tree2)
        
        nodes1, a1, d_T1 = {}, [], []
        for idx, leaf in enumerate(treeleaf1):
            nodes1[idx] = treeleaf1[leaf]['dmus'].tolist()
            a1.append(treeleaf1[leaf]['a'])
            d_T1.append(treeleaf1[leaf]['y'])
        a1 = np.array(a1)
        d_T1 = np.array(d_T1)

        nodes2, a2, d_T2 = {}, [], []
        for idx, leaf in enumerate(treeleaf2):
            nodes2[idx] = treeleaf2[leaf]['dmus'].tolist()
            a2.append(treeleaf2[leaf]['a'])
            d_T2.append(treeleaf2[leaf]['y'])
        a2 = np.array(a2)
        d_T2 = np.array(d_T2)
        #######################
        with open(os.path.join(tree_dir, 'nodes1.pkl'), 'wb') as f:
            pickle.dump(nodes1, f)
        with open(os.path.join(tree_dir, 'nodes2.pkl'), 'wb') as f:
            pickle.dump(nodes2, f)

        np.save(os.path.join(tree_dir, 'a1.npy'), a1)
        np.save(os.path.join(tree_dir, 'd_T1.npy'), d_T1)
        np.save(os.path.join(tree_dir, 'a2.npy'), a2)
        np.save(os.path.join(tree_dir, 'd_T2.npy'), d_T2)

        #######################
        dfa_selected = dfA[['x1', 'x2', 'x3']]
        dfb_selected = dfB[['x1', 'x2', 'x3']]
        x = np.concatenate([dfa_selected.values, dfb_selected.values], axis=0)
        dfa_selected = dfA[['y1', 'y2', 'y3']]
        dfb_selected = np.concatenate([dfB[['y1']].values, np.zeros((50, 2))], axis=1)
        y = np.concatenate([dfa_selected, dfb_selected], axis=0)
        #######################
        excel_path = os.path.join(iter_dir, 'data.xlsx')
        with pd.ExcelWriter(excel_path) as writer:
            pd.DataFrame(x, columns=['x1', 'x2', 'x3']).to_excel(writer, sheet_name='x', index=False)
            pd.DataFrame(y, columns=['y1', 'y2', 'y3']).to_excel(writer, sheet_name='y', index=False)



        Efficiencies = {}


        #######################
        alphas=[]
        betas=[]
        Results=[]
        lambdas_1=[]

        for o in N1:
            alpha = {}
            beta = {}
            lambdas = {}
            model = Model("DMU_Optimization")
            for i in range(m):
                for j in N1:
                    alpha[i, j] = model.addVar(vtype=GRB.CONTINUOUS, lb=0.6, ub=0.85, name=f"alpha_{i}_{j}_0")
            beta[o, 0] = model.addVar(vtype=GRB.CONTINUOUS, lb=0,ub=1, name=f"beta_{j}_0")
            beta[o, 1] = model.addVar(vtype=GRB.CONTINUOUS,lb=0,ub=1, name=f"beta_{j}_1")

            for j in N1_bar:
                lambdas[j, 0] = model.addVar(vtype=GRB.CONTINUOUS,lb=0, ub=1, name=f"lambda_{j}_0")
            for j in N2_bar:
                lambdas[j, 1] = model.addVar(vtype=GRB.CONTINUOUS, lb=0, ub=1, name=f"lambda_{j}_1")

        
            model.setParam('DualReductions', 0)
            model.setObjective(
        (beta[o, 0] + beta[o,1])/2, GRB.MAXIMIZE
        )
        
            
            R_minus = [x[o, i] - min(x[:, i]) for i in range(m)]
            R_plus = [max(y[:, r]) - y[o, r] for r in range(q)]
            

            model.addConstr(
                    quicksum(lambdas[j, 0] * y[j,0] for j in N1_bar) >= y[o,0] + beta[o, 0] * R_plus[0]
                )
            model.addConstr(
                    quicksum(lambdas[j, 1] * y[j,1] for j in N2_bar) >= y[o,1] + beta[o, 1] * R_plus[1]
                )
            model.addConstr(
                    quicksum(lambdas[j, 1] * y[j,2] for j in N2_bar) >= y[o,2] + beta[o, 1] * R_plus[2]
                )
            

            for i in range(m):  

                model.addConstr(
                        quicksum(lambdas[j, 0] * alpha[i, j] * x[j,i] for j in N1) + quicksum(lambdas[j, 0] * x[j,i] for j in N2)
                        <= alpha[i, o] * x[o,i] - beta[o, 0] * alpha[i, o] * R_minus[i]
                    )
                
                model.addConstr(
                        quicksum(lambdas[j, 1] * (1-alpha[i, j]) * x[j,i] for j in N1)
                        <= (1-alpha[i, o]) * x[o,i] - beta[o, 1] * (1-alpha[i, o]) * R_minus[i]
                    )
                
            model.addConstr(quicksum(lambdas[j, 0] for j in N1_bar) == 1)
            model.addConstr(quicksum(lambdas[j, 1] for j in N2_bar) == 1)

            model.optimize()

            if model.status == GRB.OPTIMAL:
                alpha_values1 = model.getAttr("x", alpha)
                beta_values1 = model.getAttr("x", beta)
                lambda_values1 = model.getAttr("x", lambdas)
                for key, value in alpha_values1.items():
                    if key[1]==o:
                            alphas.append({
                                    "DMU": o,
                                    "alphas_RDM": {'key':key, 'value': value}
                                })
                for key,value in lambda_values1.items():
                    lambdas_1.append({
                                    "DMU": o,
                                    "lambda": {'key':key, 'value': value}
                                })
                for key, value in beta_values1.items():
                    if key[0]==o:
                        betas.append({
                                    "DMU": o,
                                    "betas": {'key':key, 'value': value}
                                })
                        
                objective_value = model.objVal
                Results.append({"DMU":o, "efficiency_RDM":1-objective_value})
            else:
                print("No optimal solution found.")


        dmu_values = {}
        for item in alphas:
            dmu = item['DMU']
            value = item['alphas_RDM']['value']
            dmu_values.setdefault(dmu, []).append(value)
        values_list = list(dmu_values.values())



        for o in N2:
            alpha = {}
            beta = {}
            lambdas = {}
            model = Model("DMU_Optimization")
            for i in range(m):
                for j in N1:
                    alpha[i, j] = model.addVar(vtype=GRB.CONTINUOUS, lb=0.6, ub=0.85, name=f"alpha_{i}_{j}_0")
            beta[o, 0] = model.addVar(vtype=GRB.CONTINUOUS, lb=0, ub=1,name=f"beta_{j}_0")

            for j in N1_bar:
                lambdas[j, 0] = model.addVar(vtype=GRB.CONTINUOUS,lb=0, ub=1,name=f"lambda_{j}_0")

            model.setParam('DualReductions', 0)
            model.setObjective(
        (beta[o, 0]), GRB.MAXIMIZE
        )
            
            R_minus = [x[o, i] - min(x[:, i]) for i in range(m)]
            R_plus = [max(y[:, r]) - y[o, r] for r in range(q)]

            model.addConstr(
                    quicksum(lambdas[j, 0] * y[j,0] for j in N1_bar) >= y[o,0] + beta[o, 0] * R_plus[0]
                )
            
            for i in range(m):  

                model.addConstr(
                        quicksum(lambdas[j, 0] * values_list[j][i] * x[j,i] for j in N1) + quicksum(lambdas[j, 0] * x[j,i] for j in N2)
                        <=  x[o,i] - beta[o, 0]* R_minus[i]
                    )
                
            model.addConstr(quicksum(lambdas[j, 0] for j in N1_bar) == 1)


        
            
            model.optimize()

            if model.status == GRB.OPTIMAL:
                alpha_values1 = model.getAttr("x", alpha)
                beta_values1 = model.getAttr("x", beta)
                lambda_values1 = model.getAttr("x", lambdas)
                for key, value in alpha_values1.items():
                    if key[1]==o:
                            alphas.append({
                                    "DMU": o,
                                    "alphas": {'key':key, 'value': value}
                                })
                for key,value in lambda_values1.items():
                    lambdas_1.append({
                                    "DMU": o,
                                    "lambda": {'key':key, 'value': value}
                                })
                for key, value in beta_values1.items():
                    if key[0]==o:
                        betas.append({
                                    "DMU": o,
                                    "betas": {'key':key, 'value': value}
                                })
                        
                objective_value = model.objVal
                Results.append({"DMU":o, "efficiency_RDM":1-objective_value})
            else:
                print("No optimal solution found.")
        Efficiencies['RDM'] = Results
        # RDM FDH
        Nalphas=[]
        betas=[]
        Results=[]
        lambdas_1=[]
        alphas = []
        for o in N1:
            alpha = {}
            beta = {}
            lambdas = {}
            model = Model("DMU_Optimization")
            for i in range(m):
                for j in N1:
                    alpha[i, j] = model.addVar(vtype=GRB.CONTINUOUS, lb=0.6, ub=0.85, name=f"alpha_{i}_{j}_0")
            beta[o, 0] = model.addVar(vtype=GRB.CONTINUOUS, lb=0, ub=1, name=f"beta_{j}_0")
            beta[o, 1] = model.addVar(vtype=GRB.CONTINUOUS,  lb=0, ub=1,name=f"beta_{j}_1")

            for j in N1_bar:
                lambdas[j, 0] = model.addVar(vtype=GRB.BINARY,lb=0, ub=1, name=f"lambda_{j}_0")
            for j in N2_bar:
                lambdas[j, 1] = model.addVar(vtype=GRB.BINARY, lb=0, ub=1, name=f"lambda_{j}_1") 

        
            model.setParam('DualReductions', 0)
            model.setObjective(
        (beta[o, 0] + beta[o,1])/2, GRB.MAXIMIZE
        )
            
            R_minus = [x[o, i] - min(x[:, i]) for i in range(m)]
            R_plus = [max(y[:, r]) - y[o, r] for r in range(q)]
            
            model.addConstr(
                    quicksum(lambdas[j, 0] * y[j,0] for j in N1_bar) >= y[o,0] + beta[o, 0] * R_plus[0]
                )
            model.addConstr(
                    quicksum(lambdas[j, 1] * y[j,1] for j in N2_bar) >= y[o,1] + beta[o, 1] * R_plus[1]
                )
            model.addConstr(
                    quicksum(lambdas[j, 1] * y[j,2] for j in N2_bar) >= y[o,2] + beta[o, 1] * R_plus[2]
                )
        

            for i in range(m):  

                model.addConstr(
                        quicksum(lambdas[j, 0] * alpha[i, j] * x[j,i] for j in N1) + quicksum(lambdas[j, 0] * x[j,i] for j in N2)
                        <= alpha[i, o] * x[o,i] - beta[o, 0] * alpha[i, o] * R_minus[i]
                    )
                model.addConstr(
                        quicksum(lambdas[j, 1] * (1-alpha[i, j]) * x[j,i] for j in N1)
                        <= (1-alpha[i, o]) * x[o,i] - beta[o, 1] * (1-alpha[i, o]) * R_minus[i]
                    )
                
            model.addConstr(quicksum(lambdas[j, 0] for j in N1_bar) == 1)
            model.addConstr(quicksum(lambdas[j, 1] for j in N2_bar) == 1)

            model.optimize()

            if model.status == GRB.OPTIMAL:
                alpha_values1 = model.getAttr("x", alpha)
                beta_values1 = model.getAttr("x", beta)
                lambda_values1 = model.getAttr("x", lambdas)
                for key, value in alpha_values1.items():
                    if key[1]==o:
                            alphas.append({
                                    "DMU": o,
                                    "alphas_RDM_FDH": {'key':key, 'value': value}
                                })
                for key,value in lambda_values1.items():
                    lambdas_1.append({
                                    "DMU": o,
                                    "lambda": {'key':key, 'value': value}
                                })
                for key, value in beta_values1.items():
                    if key[0]==o:
                        betas.append({
                                    "DMU": o,
                                    "betas": {'key':key, 'value': value}
                                })
                        
                objective_value = model.objVal
                Results.append({"DMU":o, "efficiency_RDM_FDH":1-objective_value})
            else:
                print("No optimal solution found.")

        dmu_values = {}
        for item in alphas:
            print(item)
            dmu = item['DMU']
            value = item['alphas_RDM_FDH']['value']
            dmu_values.setdefault(dmu, []).append(value)
        values_list = list(dmu_values.values())


        for o in N2:
            alpha = {}
            beta = {}
            lambdas = {}
            model = Model("DMU_Optimization")
            for i in range(m):
                for j in N1:
                    alpha[i, j] = model.addVar(vtype=GRB.CONTINUOUS, lb=0.1, ub=0.4, name=f"alpha_{i}_{j}_0")
            beta[o, 0] = model.addVar(vtype=GRB.CONTINUOUS, lb=0, ub=1, name=f"beta_{j}_0")

            for j in N1_bar:
                lambdas[j, 0] = model.addVar(vtype=GRB.BINARY,lb=0, ub=1, name=f"lambda_{j}_0")  

        
            model.setParam('DualReductions', 0)
            model.setObjective(
        (beta[o, 0]), GRB.MAXIMIZE
        )
            
            R_minus = [x[o, i] - min(x[:, i]) for i in range(m)]
            R_plus = [max(y[:, r]) - y[o, r] for r in range(q)]

            model.addConstr(
                    quicksum(lambdas[j, 0] * y[j,0] for j in N1_bar) >= y[o,0] + beta[o, 0] * R_plus[0]
                )

            for i in range(m):  
                model.addConstr(
                        quicksum(lambdas[j, 0] * values_list[j][i] * x[j,i] for j in N1) + quicksum(lambdas[j, 0] * x[j,i] for j in N2)
                        <=  x[o,i] - beta[o, 0]* R_minus[i]
                    )
                
            model.addConstr(quicksum(lambdas[j, 0] for j in N1_bar) == 1)
            
            model.optimize()

            if model.status == GRB.OPTIMAL:
                alpha_values1 = model.getAttr("x", alpha)
                beta_values1 = model.getAttr("x", beta)
                lambda_values1 = model.getAttr("x", lambdas)
                for key, value in alpha_values1.items():
                    if key[1]==o:
                            alphas.append({
                                    "DMU": o,
                                    "alphas": {'key':key, 'value': value}
                                })
                for key,value in lambda_values1.items():
                    lambdas_1.append({
                                    "DMU": o,
                                    "lambda": {'key':key, 'value': value}
                                })
                for key, value in beta_values1.items():
                    if key[0]==o:
                        betas.append({
                                    "DMU": o,
                                    "betas": {'key':key, 'value': value}
                                })
                        
                objective_value = model.objVal
                Results.append({"DMU":o, "efficiency_RDM_FDH":1-objective_value})

            else:
                print("No optimal solution found.")
        Efficiencies['RDMFDH'] = Results
        #EAT FDH
        alphas=[]
        betas=[]
        Results=[]
        lambdas_1=[]

        for o in N1:
            alpha = {}
            beta = {}
            lambdas = {}
            lambdas_dash={}
            model = Model("DMU_Optimization")
            for t in nodes1:
                alpha[t] = model.addVar(vtype=GRB.CONTINUOUS, lb=0.6, ub=0.85, name=f"alpha_{t}_0")

            beta[o, 0] = model.addVar(vtype=GRB.CONTINUOUS, lb=0, name=f"beta_{o}_0")
            beta[o, 1] = model.addVar(vtype=GRB.CONTINUOUS,  lb=0,name=f"beta_{o}_1")

            for t in nodes1:
                lambdas[t, 0] = model.addVar(vtype=GRB.BINARY, name=f"lambda_{t}_0")
            for t in nodes2:
                lambdas_dash[t, 0] = model.addVar(vtype=GRB.BINARY, name=f"lambda_dash_{t}_0")
            for t in nodes1:
                lambdas[t, 1] = model.addVar(vtype=GRB.BINARY, name=f"lambda_{t}_1")


        
            model.setParam('DualReductions', 0)
            model.setObjective(
        (beta[o, 0] + beta[o,1])/2, GRB.MAXIMIZE
        )
            
            R_minus = [x[o, i] - min(x[:, i]) for i in range(m)]
            R_plus = [max(y[:, r]) - y[o, r] for r in range(q)]
            
            model.addConstr(
                                quicksum(lambdas[t1, 0] * d_T1[t1,0] for t1 in nodes1) + quicksum(lambdas_dash[t2, 0] * d_T2[t2][0] for t2 in nodes2) >= y[o,0] + beta[o, 0] * R_plus[0]
                            )
                    
            model.addConstr(
                                quicksum(lambdas[t, 1] * d_T1[t,1] for t in nodes1) >= y[o,1] + beta[o, 1] * R_plus[1]
                            )   
            model.addConstr(
                                quicksum(lambdas[t, 1] * d_T1[t,2] for t in nodes1) >= y[o,2] + beta[o, 1] * R_plus[2]
                            )  
            
            alpha_knot = alpha[next((key for key, values in nodes1.items() if o in values), None)]
            for i in range(m):  

                    model.addConstr(
                            quicksum(lambdas[t, 0] * alpha[t] * a1[t,i] for t in nodes1) + quicksum(lambdas_dash[t, 0] * a2[t,i] for t in nodes2)
                            <= alpha_knot * x[o,i] - beta[o, 0] * alpha_knot * R_minus[i]
                        )
                    model.addConstr(
                            quicksum(lambdas[t, 1] * (1-alpha[t]) * a1[t,i] for t in nodes1)
                            <= (1-alpha_knot) * x[o,i] - beta[o, 1] * (1-alpha_knot) * R_minus[i]
                        )
                    
            model.addConstr(quicksum(lambdas[t, 0] for t in nodes1)+ quicksum(lambdas_dash[t, 0] for t in nodes2)== 1)
            model.addConstr(quicksum(lambdas[t, 1] for t in nodes1)== 1)
            
            model.optimize()

            if model.status == GRB.OPTIMAL:
                alpha_values1 = model.getAttr("x", alpha)
                beta_values1 = model.getAttr("x", beta)
                lambda_values1 = model.getAttr("x", lambdas)
                for key, value in alpha_values1.items():
                    if key==next((key for key, values in nodes1.items() if o in values), None):
                            alphas.append({
                                                "DMU": o,
                                                "alphas": {'key':key, 'value': value}
                                            })
                for key,value in lambda_values1.items():
                    lambdas_1.append({
                                    "DMU": o,
                                    "lambda": {'key':key, 'value': value}
                                })
                for key, value in beta_values1.items():
                    if key[0]==o:
                        betas.append({
                                    "DMU": o,
                                    "betas": {'key':key, 'value': value}
                                })
                        
                objective_value = model.objVal
                Results.append({"DMU":o, "efficiency_EAT_FDH":
                                1-objective_value})
            else:
                print("No optimal solution found.")





        alpha_node=[]
        from collections import defaultdict
        alpha_sums = defaultdict(float)
        alpha_counts = defaultdict(int)
        def calculate_average_alphas(data):
            for item in data:
                key = item['alphas']['key']
                value = item['alphas']['value']
                alpha_sums[key] += value
                alpha_counts[key] += 1

            average_alphas = {key: alpha_sums[key] / alpha_counts[key] for key in alpha_sums}
            for key in average_alphas:
                alpha_node.append(average_alphas[key])
            return alpha_node
        alpha_node = calculate_average_alphas(alphas)
        print(alpha_node)




        for o in N2:
            alpha = {}
            beta = {}
            lambdas = {}
            model = Model("DMU_Optimization")
            beta[o, 0] = model.addVar(vtype=GRB.CONTINUOUS, lb=0,name=f"beta_{o}_0")

            for t in nodes1:
                lambdas[t, 0] = model.addVar(vtype=GRB.BINARY,lb=0,ub=1, name=f"lambda_{t}_0")
            for t in nodes2:
                lambdas_dash[t, 0] = model.addVar(vtype=GRB.BINARY, lb=0,ub=1,name=f"lambda_dash_{t}_0")


        
            model.setParam('DualReductions', 0)
            model.setObjective(
        (beta[o, 0]), GRB.MAXIMIZE
        )
            
            
            R_minus = [x[o, i] - min(x[:, i]) for i in range(m)]
            R_plus = [max(y[:, r]) - y[o, r] for r in range(q)]
            
            model.addConstr(
                    quicksum(lambdas[t, 0] * d_T1[t,0] for t in nodes1)+quicksum(lambdas_dash[t, 0] * d_T2[t,0] for t in nodes2) >= y[o,0] + beta[o, 0] * R_plus[0]
                )
            
            for i in range(m):  
                
            
                model.addConstr(
                        quicksum(lambdas[t, 0] *alpha_node[t]*a1[t,i] for t in nodes1) + quicksum(lambdas_dash[t, 0] * a2[t,i] for t in nodes2)
                        <=  x[o,i] - beta[o, 0]* R_minus[i]
                    )
                
            model.addConstr(quicksum(lambdas[t, 0] for t in nodes1)+ quicksum(lambdas_dash[t, 0] for t in nodes2)== 1)

            model.optimize()

            if model.status == GRB.OPTIMAL:
                alpha_values1 = model.getAttr("x", alpha)
                beta_values1 = model.getAttr("x", beta)
                lambda_values1 = model.getAttr("x", lambdas)
                for key, value in alpha_values1.items():
                            alphas.append({
                                    "DMU": o,
                                    "alphas": {'key':key, 'value': value}
                                })
                
                
                for key,value in lambda_values1.items():
                    lambdas_1.append({
                                    "DMU": o,
                                    "lambda": {'key':key, 'value': value}
                                })
                for key, value in beta_values1.items():
                    if key[0]==o:
                        betas.append({
                                    "DMU": o,
                                    "betas": {'key':key, 'value': value}
                                })
                        
                objective_value = model.objVal
                Results.append({"DMU":o, "efficiency_EAT_FDH":1-objective_value})

            
            else:
                print("No optimal solution found.")

        Efficiencies['EATFDH'] = Results
        # EAT

        alphas=[]
        betas=[]
        Results=[]
        lambdas_1=[]

        for o in N1:
            alpha = {}
            beta = {}
            lambdas = {}
            lambdas_dash={}
            model = Model("DMU_Optimization")
            for t in nodes1:
                alpha[t] = model.addVar(vtype=GRB.CONTINUOUS, lb=0.6, ub=0.85, name=f"alpha_{t}_0")

            beta[o, 0] = model.addVar(vtype=GRB.CONTINUOUS, lb=0, name=f"beta_{o}_0")
            beta[o, 1] = model.addVar(vtype=GRB.CONTINUOUS,  lb=0,name=f"beta_{o}_1")

            for t in nodes1:
                lambdas[t, 0] = model.addVar(vtype=GRB.CONTINUOUS,lb=0, name=f"lambda_{t}_0")
            for t in nodes2:
                lambdas_dash[t, 0] = model.addVar(vtype=GRB.CONTINUOUS,lb=0, name=f"lambda_dash_{t}_0")
            for t in nodes1:
                lambdas[t, 1] = model.addVar(vtype=GRB.CONTINUOUS,lb=0, name=f"lambda_{t}_1")

        
            model.setParam('DualReductions', 0)
            model.setObjective(
        (beta[o, 0] + beta[o,1])/2, GRB.MAXIMIZE
        )
            
            R_minus = [x[o, i] - min(x[:, i]) for i in range(m)]
            R_plus = [max(y[:, r]) - y[o, r] for r in range(q)]
            
            model.addConstr(
                                quicksum(lambdas[t, 0] * d_T1[t,0] for t in nodes1) + quicksum(lambdas_dash[t, 0] * d_T2[t, 0] for t in nodes2) >= y[o,0] + beta[o, 0] * R_plus[0]
                            )
                    
            model.addConstr(
                                quicksum(lambdas[t, 1] * d_T1[t,1] for t in nodes1) >= y[o,1] + beta[o, 1] * R_plus[1]
                            )   
            model.addConstr(
                                quicksum(lambdas[t, 1] * d_T1[t,2] for t in nodes1) >= y[o,2] + beta[o, 1] * R_plus[2]
                            )  
            
            alpha_knot = alpha[next((key for key, values in nodes1.items() if o in values), None)]
            for i in range(m):  

                    model.addConstr(
                            quicksum(lambdas[t, 0] * alpha[t] * a1[t,i] for t in nodes1) + quicksum(lambdas_dash[t, 0] * a2[t,i] for t in nodes2)
                            <= alpha_knot * x[o,i] - beta[o, 0] * alpha_knot * R_minus[i]
                        )
                    model.addConstr(
                            quicksum(lambdas[t, 1] * (1-alpha[t]) * a1[t,i] for t in nodes1)
                            <= (1-alpha_knot) * x[o,i] - beta[o, 1] * (1-alpha_knot) * R_minus[i]
                        )
            model.addConstr(quicksum(lambdas[t, 0] for t in nodes1)+ quicksum(lambdas_dash[t, 0] for t in nodes2)== 1)
            model.addConstr(quicksum(lambdas[t, 1] for t in nodes1)== 1)

            model.optimize()

            if model.status == GRB.OPTIMAL:
                alpha_values1 = model.getAttr("x", alpha)
                beta_values1 = model.getAttr("x", beta)
                lambda_values1 = model.getAttr("x", lambdas)
                for key, value in alpha_values1.items():
                    if key==next((key for key, values in nodes1.items() if o in values), None):
                            alphas.append({
                                                "DMU": o,
                                                "alphas": {'key':key, 'value': value}
                                            })
                for key,value in lambda_values1.items():
                    lambdas_1.append({
                                    "DMU": o,
                                    "lambda": {'key':key, 'value': value}
                                })
                for key, value in beta_values1.items():
                    if key[0]==o:
                        betas.append({
                                    "DMU": o,
                                    "betas": {'key':key, 'value': value}
                                })
                        
                objective_value = model.objVal
                Results.append({"DMU":o, "efficiency_EAT":
                                1-objective_value})
            else:
                print("No optimal solution found.")
                


        alpha_node=[]
        from collections import defaultdict
        alpha_sums = defaultdict(float)
        alpha_counts = defaultdict(int)

        def calculate_average_alphas(data):
            for item in data:
                key = item['alphas']['key']
                value = item['alphas']['value']
                alpha_sums[key] += value
                alpha_counts[key] += 1

            average_alphas = {key: alpha_sums[key] / alpha_counts[key] for key in alpha_sums}
            for key in average_alphas:
                alpha_node.append(average_alphas[key])
            return alpha_node

        alpha_node = calculate_average_alphas(alphas)
        print(alpha_node)


        import pandas as pd
        for o in N2:
            alpha = {}
            beta = {}
            lambdas = {}
            model = Model("DMU_Optimization")
            beta[o, 0] = model.addVar(vtype=GRB.CONTINUOUS, lb=0,name=f"beta_{o}_0")

            for t in nodes1:
                lambdas[t, 0] = model.addVar(vtype=GRB.CONTINUOUS,lb=0, name=f"lambda_{t}_0")
            for t in nodes2:
                lambdas_dash[t, 0] = model.addVar(vtype=GRB.CONTINUOUS, lb=0,name=f"lambda_dash_{t}_0")


        
            model.setParam('DualReductions', 0)
            model.setObjective(
        (beta[o, 0]), GRB.MAXIMIZE
        )

            R_minus = [x[o, i] - min(x[:, i]) for i in range(m)]
            R_plus = [max(y[:, r]) - y[o, r] for r in range(q)]

            model.addConstr(
                    quicksum(lambdas[t, 0] * d_T1[t,0] for t in nodes1)+quicksum(lambdas_dash[t, 0] * d_T2[t,0] for t in nodes2) >= y[o,0] + beta[o, 0] * R_plus[0]
                )
            
            for i in range(m):  
                
            
                model.addConstr(
                        quicksum(lambdas[t, 0] *alpha_node[t]*a1[t,i] for t in nodes1) + quicksum(lambdas_dash[t, 0] * a2[t,i] for t in nodes2)
                        <=  x[o,i] - beta[o, 0]* R_minus[i]
                    )
                
            model.addConstr(quicksum(lambdas[t, 0] for t in nodes1)+ quicksum(lambdas_dash[t, 0] for t in nodes2)== 1)

        
            
            model.optimize()


            if model.status == GRB.OPTIMAL:
                alpha_values1 = model.getAttr("x", alpha)
                beta_values1 = model.getAttr("x", beta)
                lambda_values1 = model.getAttr("x", lambdas)
                for key, value in alpha_values1.items():
                            alphas.append({
                                    "DMU": o,
                                    "alphas": {'key':key, 'value': value}
                                })
                
                
                for key,value in lambda_values1.items():
                    lambdas_1.append({
                                    "DMU": o,
                                    "lambda": {'key':key, 'value': value}
                                })
                for key, value in beta_values1.items():
                    if key[0]==o:
                        betas.append({
                                    "DMU": o,
                                    "betas": {'key':key, 'value': value}
                                })
                        
                objective_value = model.objVal
                Results.append({"DMU":o, "efficiency_EAT":1-objective_value})

            
            else:
                print("No optimal solution found.")
        Efficiencies['EAT'] = Results
        #######################



        #######################
        dfres4 = pd.DataFrame(Efficiencies['EAT'])
        dfres3 = pd.DataFrame(Efficiencies['EATFDH'])
        dfres2 = pd.DataFrame(Efficiencies['RDMFDH'])
        dfres1 = pd.DataFrame(Efficiencies['RDM'])

        df_combined = pd.DataFrame()
        df_combined = pd.concat([
            dfres1,
            dfres2,
            dfres3,
            dfres4
        ], axis=1)
        print(df_combined.columns)
        df_combined = df_combined[['efficiency_RDM', 'efficiency_RDM_FDH', 'efficiency_EAT', 'efficiency_EAT_FDH']]
        #######################


        #######################
        dfstats1 = pd.DataFrame(list(stats(df_combined, 'efficiency_RDM').items()), columns=['Index', 'RDM'])
        dfstats2 = pd.DataFrame(list(stats(df_combined, 'efficiency_RDM_FDH').items()), columns=['Index', 'RDM_FDH'])
        dfstats3 = pd.DataFrame(list(stats(df_combined, 'efficiency_EAT').items()), columns=['Index', 'EAT'])
        dfstats4 = pd.DataFrame(list(stats(df_combined, 'efficiency_EAT_FDH').items()), columns=['Index', 'EAT_FDH'])

        df_merged = dfstats1.merge(dfstats2, on='Index', how='outer') \
                            .merge(dfstats3, on='Index', how='outer') \
                            .merge(dfstats4, on='Index', how='outer')
        #######################

        #######################
        dfeff = df_combined.copy()
        dfeff.rename(columns={'efficiency_EAT_FDH':'E_CRE',
                            'efficiency_EAT':'E_NCRE',
                            'efficiency_RDM_FDH':'E_NCR',
                            'efficiency_RDM':'E_CR'}, inplace=True)
        CrM = dfeff.iloc[:, 0:4].corr()
        #######################


        #######################
        pairs = [('E_CR', 'E_NCR'), ('E_CR', 'E_NCRE'), ('E_CR', 'E_CRE'),
                ('E_NCR', 'E_NCRE'), ('E_NCR', 'E_CRE'),
                ('E_NCRE', 'E_CRE')]

        sns.set(style="whitegrid")
        plt.figure(figsize=(10, 10), dpi=300)  

        for i, (var1, var2) in enumerate(pairs, 1):
            plt.subplot(2, 3, i)

            x = dfeff[f'{var1}']
            y = dfeff[f'{var2}']

            plt.scatter(x, y, label=f'{var1} vs {var2}', color='blue')
            plt.plot([0, 1], [0, 1], color='red', linestyle='--')  

            r = np.corrcoef(x, y)[0, 1]
            plt.text(0.05, 0.9, f'r = {r:.4f}', transform=plt.gca().transAxes,
                    fontsize=12, fontweight='bold', color='black',
                    bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

            plt.xlim(0, 1)
            plt.ylim(0, 1)
            plt.xlabel(var1)
            plt.ylabel(var2)
            plt.title(f'{var1} vs {var2}')

            plt.gca().set_aspect('equal', adjustable='box')

        plt.tight_layout(pad=0.0)  

        save_path = os.path.join(iter_dir, 'pairwise_scatter.png')
        plt.savefig(save_path, dpi=300, bbox_inches='tight')
        plt.close()
        #######################
        # CEAT = E_CRE = EAT_FDH
        models = ['E_CR', 'E_NCR', 'E_NCRE', 'E_CRE']
        results = []

        for i in range(len(models)):
            for j in range(i + 1, len(models)):
                M1 = models[i]
                M2 = models[j]
                data1 = dfeff[M1].dropna().values
                data2 = dfeff[M2].dropna().values
                
                ks_stat, p_value = ks_2samp(data1, data2)
                results.append([M1, M2, ks_stat, p_value])

        results_df = pd.DataFrame(results, columns=['Model1', 'Model2', 'TKS', 'p-value'])
        #######################

        df_combined.to_csv(os.path.join(iter_dir, 'efficiencies.csv'), index=False)
        df_merged.to_csv(os.path.join(iter_dir, 'stats.csv'), index=False)
        CrM.to_csv(os.path.join(iter_dir, 'CrM.csv'), index=False)
        results_df.to_csv(os.path.join(iter_dir, 'kstest.csv'), index=False)
# Out:
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x7c1abeea
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [2e+01, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.07s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.6177140
#
# Root relaxation: objective 6.696348e-01, 577 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.66963    0   19    0.61771    0.66963  8.41%     -    0s
#      0     0    0.66963    0   19    0.61771    0.66963  8.41%     -    0s
#      0     2    0.66963    0   19    0.61771    0.66963  8.41%     -    0s
# * 1156    65              45       0.6177141    0.61777  0.01%  14.2    0s
# * 1160    65              47       0.6177141    0.61777  0.01%  14.2    0s
# * 1161    65              46       0.6177141    0.61777  0.01%  14.2    0s
#
# Explored 1206 nodes (17143 simplex iterations) in 0.79 seconds (0.42 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 0.617714 0.617714 0.617714 0.617714
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.177141057498e-01, best bound 6.177673535637e-01, gap 0.0086%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x1f3bc369
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [1e+01, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8422326
#
# Root relaxation: objective 8.937978e-01, 498 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.89380    0   18    0.84223    0.89380  6.12%     -    0s
#      0     0    0.89380    0   18    0.84223    0.89380  6.12%     -    0s
#      0     2    0.89380    0   18    0.84223    0.89380  6.12%     -    0s
# H   64    77                       0.8503843    0.87556  2.96%  50.7    0s
# H   66    77                       0.8719010    0.87556  0.42%  49.5    0s
# H   70    77                       0.8719413    0.87556  0.42%  47.3    0s
# *  362   289              24       0.8720108    0.87493  0.33%  28.3    0s
# *  477   398              36       0.8737577    0.87493  0.13%  24.2    0s
# H  545   381                       0.8737577    0.87480  0.12%  23.0    0s
# *  776   438              29       0.8737700    0.87459  0.09%  20.3    0s
# *  823   469              34       0.8737755    0.87459  0.09%  22.1    0s
# *  903   466              38       0.8737798    0.87436  0.07%  21.9    0s
# * 1018   461              39       0.8737907    0.87436  0.07%  21.7    0s
# * 1120   434              31       0.8737962    0.87436  0.07%  21.3    0s
# * 1132   434              28       0.8737999    0.87436  0.06%  21.3    0s
# * 1199   451              40       0.8738034    0.87436  0.06%  21.6    0s
# * 1427   459              35       0.8738064    0.87407  0.03%  20.1    0s
# * 1630   504              68       0.8738148    0.87395  0.02%  18.9    0s
# * 1701   460              42       0.8738220    0.87391  0.01%  18.8    0s
#
# Explored 1971 nodes (35330 simplex iterations) in 0.95 seconds (0.72 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.873822 0.873815 0.873806 ... 0.87377
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.738219614043e-01, best bound 8.739091440487e-01, gap 0.0100%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x2ab2e0fa
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 6e+01]
#   QLMatrix range   [1e+00, 6e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [1e+01, 2e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.6988832
#
# Root relaxation: objective 7.136895e-01, 568 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.71369    0   17    0.69888    0.71369  2.12%     -    0s
# H    0     0                       0.6988835    0.71369  2.12%     -    0s
#      0     0    0.71270    0   19    0.69888    0.71270  1.98%     -    0s
#      0     0    0.71059    0   17    0.69888    0.71059  1.67%     -    0s
#      0     2    0.71059    0   17    0.69888    0.71059  1.67%     -    0s
# H  104    13                       0.6988835    0.70462  0.82%  11.6    0s
#
# Cutting planes:
#   RLT: 2
#
# Explored 204 nodes (3173 simplex iterations) in 0.29 seconds (0.18 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.698884 0.698883
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.988835242123e-01, best bound 6.989490120132e-01, gap 0.0094%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x53a6a567
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   QMatrix range    [1e+00, 9e+01]
#   QLMatrix range   [1e+00, 9e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [3e+01, 5e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.6998691
#
# Root relaxation: objective 7.325083e-01, 564 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.73251    0   15    0.69987    0.73251  4.66%     -    0s
#      0     0    0.73250    0   15    0.69987    0.73250  4.66%     -    0s
#      0     0    0.73239    0   15    0.69987    0.73239  4.65%     -    0s
#      0     2    0.73239    0   15    0.69987    0.73239  4.65%     -    0s
# H   63    29                       0.6998692    0.71064  1.54%  35.0    0s
# *  193   103              21       0.7000971    0.71064  1.51%  24.9    0s
# *  210   103              19       0.7012084    0.71064  1.35%  23.2    0s
# *  211   103              19       0.7012144    0.71064  1.34%  24.2    0s
# *  274   167              17       0.7040938    0.70688  0.40%  19.7    0s
# *  466   259              34       0.7045032    0.70688  0.34%  13.1    0s
# *  481   259              25       0.7046097    0.70688  0.32%  12.7    0s
# *  571   279              24       0.7046129    0.70601  0.20%  12.6    0s
# H  603   279                       0.7049508    0.70594  0.14%  12.3    0s
# *  616   279              44       0.7049598    0.70594  0.14%  12.2    0s
# *  755   342              26       0.7052223    0.70594  0.10%  11.4    0s
# *  834   387              23       0.7054609    0.70594  0.07%  10.6    0s
# *  928   387              29       0.7056350    0.70594  0.04%   9.8    0s
# *  933   454              28       0.7057983    0.70594  0.02%  10.4    0s
# * 1089   501              29       0.7058009    0.70593  0.02%   9.9    0s
# * 1112   501              23       0.7058066    0.70593  0.02%   9.8    0s
# * 1117   501              23       0.7058109    0.70593  0.02%   9.7    0s
# * 1275   521              28       0.7059100    0.70593  0.00%   8.9    0s
#
# Cutting planes:
#   RLT: 2
#
# Explored 1477 nodes (12696 simplex iterations) in 0.88 seconds (0.36 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 0.70591 0.705811 0.705807 ... 0.704951
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.059099514503e-01, best bound 7.059329468486e-01, gap 0.0033%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0xfdc387d9
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   QMatrix range    [1e+00, 5e+01]
#   QLMatrix range   [1e+00, 5e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [1e+01, 4e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.7721418
#
# Root relaxation: objective 8.044273e-01, 636 iterations, 0.10 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.80443    0   18    0.77214    0.80443  4.18%     -    0s
#      0     0    0.80443    0   18    0.77214    0.80443  4.18%     -    0s
#      0     2    0.80443    0   18    0.77214    0.80443  4.18%     -    0s
# H   82    41                       0.7723557    0.77409  0.22%  13.5    0s
# H  381   161                       0.7724912    0.77386  0.18%  10.1    0s
# *  430   159              35       0.7724970    0.77274  0.03%   9.1    0s
# *  507   178              34       0.7725069    0.77257  0.01%   9.0    0s
#
# Explored 585 nodes (6390 simplex iterations) in 0.75 seconds (0.24 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 0.772507 0.772497 0.772491 ... 0.772142
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.725068993799e-01, best bound 7.725578337599e-01, gap 0.0066%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x35c0ba94
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 6e+01]
#   QLMatrix range   [1e+00, 6e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [8e+00, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8158845
#
# Root relaxation: objective 8.383769e-01, 548 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.83838    0   13    0.81588    0.83838  2.76%     -    0s
#      0     0    0.83834    0   13    0.81588    0.83834  2.75%     -    0s
#      0     0    0.83830    0   13    0.81588    0.83830  2.75%     -    0s
#      0     2    0.83830    0   13    0.81588    0.83830  2.75%     -    0s
# H   27    14                       0.8158845    0.81885  0.36%  11.5    0s
# *  345    59              32       0.8158847    0.81610  0.03%   8.1    0s
# *  365    59              37       0.8158847    0.81610  0.03%   7.8    0s
#
# Explored 435 nodes (3549 simplex iterations) in 0.49 seconds (0.20 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.815885 0.815885 0.815885
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.158847252284e-01, best bound 8.158860669488e-01, gap 0.0002%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x2f98ead2
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   QMatrix range    [1e+00, 6e+01]
#   QLMatrix range   [1e+00, 6e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [6e+00, 1e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8261797
#
# Root relaxation: objective 8.857322e-01, 564 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.88573    0   17    0.82618    0.88573  7.21%     -    0s
# H    0     0                       0.8638830    0.88573  2.53%     -    0s
#      0     0    0.88333    0   17    0.86388    0.88333  2.25%     -    0s
#      0     2    0.88296    0   17    0.86388    0.88296  2.21%     -    0s
# H  376   314                       0.8675840    0.86920  0.19%  24.7    0s
# H  395   314                       0.8677498    0.86920  0.17%  23.7    0s
# H  523   321                       0.8677547    0.86792  0.02%  20.6    0s
# *  621   275              25       0.8677548    0.86779  0.00%  19.5    0s
#
# Cutting planes:
#   RLT: 3
#
# Explored 667 nodes (12719 simplex iterations) in 0.84 seconds (0.54 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 0.867755 0.867755 0.86775 ... 0.82618
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.677547780873e-01, best bound 8.677884466904e-01, gap 0.0039%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x6464b33e
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [4e+00, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8161450
#
# Root relaxation: objective 8.350553e-01, 507 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.83506    0   19    0.81614    0.83506  2.32%     -    0s
#      0     0    0.83488    0   19    0.81614    0.83488  2.30%     -    0s
#      0     0    0.83482    0   19    0.81614    0.83482  2.29%     -    0s
#      0     2    0.83482    0   19    0.81614    0.83482  2.29%     -    0s
# *  395    26              32       0.8161452    0.81620  0.01%  15.3    0s
# *  396    26              32       0.8161452    0.81620  0.01%  15.2    0s
#
# Cutting planes:
#   RLT: 2
#
# Explored 423 nodes (6613 simplex iterations) in 0.59 seconds (0.28 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.816145 0.816145 0.816145
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.161451870317e-01, best bound 8.161657816456e-01, gap 0.0025%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0xbe644078
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   QMatrix range    [1e+00, 7e+01]
#   QLMatrix range   [1e+00, 7e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [5e+00, 2e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8579551
#
# Root relaxation: objective 8.764186e-01, 511 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.87642    0   16    0.85796    0.87642  2.15%     -    0s
#      0     0    0.87609    0   16    0.85796    0.87609  2.11%     -    0s
#      0     0    0.87566    0   16    0.85796    0.87566  2.06%     -    0s
#      0     2    0.87566    0   16    0.85796    0.87566  2.06%     -    0s
#
# Cutting planes:
#   RLT: 1
#
# Explored 238 nodes (5061 simplex iterations) in 0.50 seconds (0.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.857955
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.579550646667e-01, best bound 8.579941312898e-01, gap 0.0046%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x10fd1ef7
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   QMatrix range    [1e+00, 5e+01]
#   QLMatrix range   [1e+00, 5e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [4e+00, 2e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.01s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8295536
#
# Root relaxation: objective 8.483455e-01, 557 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.84835    0   18    0.82955    0.84835  2.27%     -    0s
# H    0     0                       0.8295538    0.84835  2.27%     -    0s
#      0     0    0.84711    0   15    0.82955    0.84711  2.12%     -    0s
#      0     0    0.84695    0   15    0.82955    0.84695  2.10%     -    0s
#      0     0    0.84687    0   15    0.82955    0.84687  2.09%     -    0s
#      0     0    0.84687    0   15    0.82955    0.84687  2.09%     -    0s
#      0     2    0.84687    0   15    0.82955    0.84687  2.09%     -    0s
#
# Cutting planes:
#   RLT: 3
#
# Explored 54 nodes (2689 simplex iterations) in 0.52 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.829554 0.829554
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.295538226774e-01, best bound 8.296106235220e-01, gap 0.0068%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x512f18ac
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [1e+01, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.5466376
#
# Root relaxation: objective 5.692442e-01, 547 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.56924    0   16    0.54664    0.56924  4.14%     -    0s
#      0     0    0.56346    0   17    0.54664    0.56346  3.08%     -    0s
#      0     0    0.56298    0   17    0.54664    0.56298  2.99%     -    0s
#      0     2    0.56086    0   17    0.54664    0.56086  2.60%     -    0s
#
# Explored 37 nodes (1777 simplex iterations) in 0.26 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.546638
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.466375738636e-01, best bound 5.466380767534e-01, gap 0.0001%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x33c30a27
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   QMatrix range    [1e+00, 9e+01]
#   QLMatrix range   [1e+00, 9e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 2e+01]
#   QRHS range       [2e+01, 4e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.7727982
#
# Root relaxation: objective 7.995991e-01, 559 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.79960    0   13    0.77280    0.79960  3.47%     -    0s
#      0     0    0.79944    0   13    0.77280    0.79944  3.45%     -    0s
#      0     2    0.79944    0   13    0.77280    0.79944  3.45%     -    0s
# H   39    16                       0.7727982    0.77953  0.87%  15.9    0s
# H   43    16                       0.7727983    0.77953  0.87%  16.4    0s
#
# Explored 502 nodes (4216 simplex iterations) in 0.73 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 0.772798 0.772798 0.772798
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (4.0373e-06) exceeds tolerance
# Best objective 7.727983374359e-01, best bound 7.728547890942e-01, gap 0.0073%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x69a3e2a9
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   QMatrix range    [1e+00, 6e+01]
#   QLMatrix range   [1e+00, 6e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [1e+00, 8e+00]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.5717645
#
# Root relaxation: interrupted, 350 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0          -    0         0.57176    0.57176  0.00%     -    0s
#
# Explored 1 nodes (350 simplex iterations) in 0.06 seconds (0.02 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.571764
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.717644584908e-01, best bound 5.717649651787e-01, gap 0.0001%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0xd0dd7ff3
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   QMatrix range    [1e+00, 1e+02]
#   QLMatrix range   [1e+00, 1e+02]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [4e+01, 5e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8387487
#
# Root relaxation: objective 8.397681e-01, 495 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.83977    0   13    0.83875    0.83977  0.12%     -    0s
# H    0     0                       0.8387490    0.83977  0.12%     -    0s
#      0     0    0.83960    0   13    0.83875    0.83960  0.10%     -    0s
#      0     0    0.83942    0   13    0.83875    0.83942  0.08%     -    0s
#      0     2    0.83942    0   13    0.83875    0.83942  0.08%     -    0s
#
# Cutting planes:
#   RLT: 1
#
# Explored 76 nodes (1057 simplex iterations) in 0.17 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.838749 0.838749
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.387490012886e-01, best bound 8.387508237090e-01, gap 0.0002%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0xa7d8fb5a
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [2e+01, 4e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.6021200
#
# Root relaxation: objective 6.944128e-01, 607 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.69441    0   18    0.60212    0.69441  15.3%     -    0s
#      0     0    0.69344    0   18    0.60212    0.69344  15.2%     -    0s
#      0     0    0.69337    0   18    0.60212    0.69337  15.2%     -    0s
# H    0     0                       0.6021202    0.69337  15.2%     -    0s
#      0     2    0.69337    0   18    0.60212    0.69337  15.2%     -    0s
# H  121    20                       0.6021202    0.60464  0.42%  33.7    0s
#
# Cutting planes:
#   RLT: 1
#
# Explored 296 nodes (8344 simplex iterations) in 0.45 seconds (0.22 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.60212 0.60212
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.021202397124e-01, best bound 6.021361267301e-01, gap 0.0026%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x9a78a5d2
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   QMatrix range    [1e+00, 1e+02]
#   QLMatrix range   [1e+00, 1e+02]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [4e+01, 5e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.01s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8053761
#
# Root relaxation: objective 8.290139e-01, 590 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.82901    0   15    0.80538    0.82901  2.94%     -    0s
#      0     0    0.82871    0   15    0.80538    0.82871  2.90%     -    0s
#      0     0    0.82844    0   15    0.80538    0.82844  2.86%     -    0s
#      0     2    0.82844    0   15    0.80538    0.82844  2.86%     -    0s
#
# Explored 19 nodes (1161 simplex iterations) in 0.18 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.805376
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (2.0752e-06) exceeds tolerance
# Best objective 8.053760674706e-01, best bound 8.054042498770e-01, gap 0.0035%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x07244164
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   QMatrix range    [1e+00, 5e+01]
#   QLMatrix range   [1e+00, 5e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [5e+00, 2e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.6040342
#
# Root relaxation: objective 6.097885e-01, 523 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.60979    0   18    0.60403    0.60979  0.95%     -    0s
# H    0     0                       0.6040347    0.60979  0.95%     -    0s
#      0     0    0.60974    0   18    0.60403    0.60974  0.94%     -    0s
#      0     0    0.60974    0   18    0.60403    0.60974  0.94%     -    0s
#      0     2    0.60974    0   18    0.60403    0.60974  0.94%     -    0s
#
# Cutting planes:
#   RLT: 2
#
# Explored 177 nodes (3118 simplex iterations) in 0.57 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.604035 0.604034
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.040347269923e-01, best bound 6.040347454274e-01, gap 0.0000%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 602 nonzeros
# Model fingerprint: 0x79d4149c
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 9e+01]
#   QLMatrix range   [1e+00, 9e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [3e+01, 4e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 0 rows and 6 columns
# Presolve time: 0.01s
# Presolved: 1199 rows, 1140 columns, 4598 nonzeros
# Presolved model has 594 bilinear constraint(s)
# Variable types: 1140 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.3970632
#
# Root relaxation: objective 4.331753e-01, 505 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.43318    0    5    0.39706    0.43318  9.09%     -    0s
# H    0     0                       0.4316424    0.43318  0.36%     -    0s
#      0     0          -    0         0.43164    0.43168  0.01%     -    0s
#
# Cutting planes:
#   RLT: 8
#   PSD: 1
#
# Explored 1 nodes (505 simplex iterations) in 0.11 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.431642 0.397063
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.316424170927e-01, best bound 4.316755312737e-01, gap 0.0077%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x3acbb4f6
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   QMatrix range    [1e+00, 1e+02]
#   QLMatrix range   [1e+00, 1e+02]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [2e+01, 5e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8546216
#
# Root relaxation: objective 8.680486e-01, 510 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.86805    0   19    0.85462    0.86805  1.57%     -    0s
#      0     0    0.86743    0   19    0.85462    0.86743  1.50%     -    0s
#      0     0    0.86722    0   19    0.85462    0.86722  1.47%     -    0s
#      0     2    0.86722    0   19    0.85462    0.86722  1.47%     -    0s
# H   31    10                       0.8546218    0.85663  0.23%   8.3    0s
#
# Explored 613 nodes (8310 simplex iterations) in 1.34 seconds (0.32 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.854622 0.854622
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (2.6358e-06) exceeds tolerance
# Best objective 8.546217697981e-01, best bound 8.546476994348e-01, gap 0.0030%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x6e3e7727
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [8e+00, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.01s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.5933215
#
# Root relaxation: objective 6.141425e-01, 490 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.61414    0   16    0.59332    0.61414  3.51%     -    0s
# H    0     0                       0.5933220    0.61414  3.51%     -    0s
#      0     0    0.61414    0   16    0.59332    0.61414  3.51%     -    0s
#      0     2    0.61414    0   16    0.59332    0.61414  3.51%     -    0s
#
# Explored 54 nodes (2060 simplex iterations) in 0.35 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.593322 0.593322
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.933220098398e-01, best bound 5.933395537302e-01, gap 0.0030%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x7996dcc8
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [3e+01, 4e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.7294574
#
# Root relaxation: objective 7.481098e-01, 496 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.74811    0   19    0.72946    0.74811  2.56%     -    0s
# H    0     0                       0.7296230    0.74811  2.53%     -    0s
#      0     0    0.74810    0   19    0.72962    0.74810  2.53%     -    0s
#      0     2    0.74810    0   19    0.72962    0.74810  2.53%     -    0s
#
# Explored 140 nodes (2637 simplex iterations) in 0.36 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.729623 0.729457
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.296230483718e-01, best bound 7.296230610086e-01, gap 0.0000%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x57395570
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [1e+01, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8543338
#
# Root relaxation: objective 8.715227e-01, 542 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.87152    0   16    0.85433    0.87152  2.01%     -    0s
# H    0     0                       0.8543343    0.87152  2.01%     -    0s
#      0     0    0.87152    0   16    0.85433    0.87152  2.01%     -    0s
#      0     2    0.87152    0   16    0.85433    0.87152  2.01%     -    0s
# H   41    17                       0.8543343    0.85646  0.25%  17.9    0s
#
# Explored 813 nodes (8195 simplex iterations) in 1.05 seconds (0.29 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.854334 0.854334
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.543343394796e-01, best bound 8.543942859151e-01, gap 0.0070%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x8ec17b28
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [1e+00, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.7814407
#
# Root relaxation: objective 8.043454e-01, 512 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.80435    0   21    0.78144    0.80435  2.93%     -    0s
#      0     0    0.80435    0   21    0.78144    0.80435  2.93%     -    0s
#      0     2    0.80435    0   21    0.78144    0.80435  2.93%     -    0s
#
# Explored 271 nodes (6244 simplex iterations) in 0.52 seconds (0.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.781441
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (1.7951e-06) exceeds tolerance
# Best objective 7.814407293097e-01, best bound 7.814476697290e-01, gap 0.0009%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 602 nonzeros
# Model fingerprint: 0x73c03c0d
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+01]
#   QMatrix range    [1e+00, 6e+01]
#   QLMatrix range   [1e+00, 6e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [7e+00, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve removed 0 rows and 6 columns
# Presolve time: 0.01s
# Presolved: 1181 rows, 1131 columns, 4523 nonzeros
# Presolved model has 585 bilinear constraint(s)
# Variable types: 1131 continuous, 0 integer (0 binary)
#
# Root relaxation: objective 3.968244e-01, 468 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.39682    0   11          -    0.39682      -     -    0s
# H    0     0                       0.1677467    0.39682   137%     -    0s
# H    0     0                       0.3963892    0.39682  0.11%     -    0s
#      0     0          -    0         0.39639    0.39639  0.00%     -    0s
#
# Cutting planes:
#   RLT: 4
#
# Explored 1 nodes (468 simplex iterations) in 0.16 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.396389 0.167747
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.963891875449e-01, best bound 3.963914935104e-01, gap 0.0006%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# ...
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.77696    0   15    0.74764    0.77696  3.92%     -    0s
#      0     0    0.77680    0   15    0.74764    0.77680  3.90%     -    0s
#      0     0    0.77660    0   15    0.74764    0.77660  3.87%     -    0s
#      0     2    0.77660    0   15    0.74764    0.77660  3.87%     -    0s
#
# Explored 107 nodes (1493 simplex iterations) in 0.48 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.747637
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.476371940350e-01, best bound 7.476487729307e-01, gap 0.0015%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x107944a9
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [2e+00, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8038469
#
# Root relaxation: objective 8.173372e-01, 531 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.81734    0   15    0.80385    0.81734  1.68%     -    0s
# H    0     0                       0.8038471    0.81734  1.68%     -    0s
#      0     0    0.81588    0   15    0.80385    0.81588  1.50%     -    0s
#      0     0    0.81556    0   15    0.80385    0.81556  1.46%     -    0s
#      0     0    0.81445    0   15    0.80385    0.81445  1.32%     -    0s
#      0     2    0.81445    0   15    0.80385    0.81445  1.32%     -    0s
#
# Explored 29 nodes (928 simplex iterations) in 0.28 seconds (0.14 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.803847 0.803847
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.038471494305e-01, best bound 8.039071379050e-01, gap 0.0075%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0xa810ec40
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [9e+00, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.7782665
#
# Root relaxation: objective 7.948852e-01, 506 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.79489    0   19    0.77827    0.79489  2.14%     -    0s
#      0     0    0.79226    0   19    0.77827    0.79226  1.80%     -    0s
#      0     0    0.79156    0   19    0.77827    0.79156  1.71%     -    0s
#      0     2    0.79156    0   19    0.77827    0.79156  1.71%     -    0s
#
# Explored 487 nodes (8897 simplex iterations) in 0.87 seconds (0.35 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.778266
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.782664509448e-01, best bound 7.783358834261e-01, gap 0.0089%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0xacc04b49
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   QMatrix range    [1e+00, 8e+01]
#   QLMatrix range   [1e+00, 8e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 5e+01]
#   QRHS range       [2e+01, 4e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.2120465
#
# Root relaxation: objective 4.556534e-01, 485 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.45565    0    2    0.21205    0.45565   115%     -    0s
# H    0     0                       0.4542099    0.45565  0.32%     -    0s
#      0     0     cutoff    0         0.45421    0.45421  0.00%     -    0s
#
# Cutting planes:
#   RLT: 3
#
# Explored 1 nodes (489 simplex iterations) in 0.20 seconds (0.05 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 0.45421 0.212046
# No other solutions better than 0.45421
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.542098728145e-01, best bound 4.542098728145e-01, gap 0.0000%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x1516462a
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 6e+01]
#   QLMatrix range   [1e+00, 6e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [1e+01, 4e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8525619
#
# Root relaxation: objective 8.627205e-01, 528 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.86272    0   14    0.85256    0.86272  1.19%     -    0s
#      0     0    0.86175    0   14    0.85256    0.86175  1.08%     -    0s
#      0     0    0.86166    0   14    0.85256    0.86166  1.07%     -    0s
#      0     0    0.86156    0   14    0.85256    0.86156  1.06%     -    0s
#      0     0    0.86155    0   14    0.85256    0.86155  1.05%     -    0s
#      0     2    0.86155    0   14    0.85256    0.86155  1.05%     -    0s
#
# Cutting planes:
#   RLT: 3
#
# Explored 25 nodes (2001 simplex iterations) in 0.43 seconds (0.22 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.852562
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.525619306813e-01, best bound 8.525684525382e-01, gap 0.0008%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0xeefb4485
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 9e+01]
#   QMatrix range    [1e+00, 7e+01]
#   QLMatrix range   [1e+00, 7e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [5e+00, 2e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8346300
#
# Root relaxation: objective 8.507520e-01, 493 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.85075    0   19    0.83463    0.85075  1.93%     -    0s
#      0     0    0.85030    0   19    0.83463    0.85030  1.88%     -    0s
#      0     0    0.85023    0   19    0.83463    0.85023  1.87%     -    0s
#      0     2    0.85023    0   19    0.83463    0.85023  1.87%     -    0s
# H   50    19                       0.8346300    0.83643  0.22%  29.1    0s
# *  481    57              34       0.8346301    0.83474  0.01%  14.3    0s
# *  622    77              42       0.8346302    0.83474  0.01%  11.7    0s
# *  651    85              41       0.8346302    0.83474  0.01%  11.5    1s
# *  857   105              43       0.8346303    0.83466  0.00%   9.4    1s
#
# Cutting planes:
#   RLT: 3
#
# Explored 898 nodes (8687 simplex iterations) in 1.15 seconds (0.38 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 0.83463 0.83463 0.83463 ... 0.83463
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.346302672366e-01, best bound 8.346645456756e-01, gap 0.0041%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x0a163205
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+01]
#   QMatrix range    [1e+00, 5e+01]
#   QLMatrix range   [1e+00, 5e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 3e+01]
#   QRHS range       [4e+00, 4e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.01s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.6864041
#
# Root relaxation: objective 7.400972e-01, 570 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.74010    0   15    0.68640    0.74010  7.82%     -    0s
# H    0     0                       0.6864474    0.74010  7.82%     -    0s
#      0     0    0.73822    0   15    0.68645    0.73822  7.54%     -    0s
# H    0     0                       0.6864477    0.73822  7.54%     -    0s
#      0     0    0.73143    0   15    0.68645    0.73143  6.55%     -    0s
#      0     2    0.71558    0   15    0.68645    0.71558  4.24%     -    0s
# *  679   105              53       0.6864482    0.68668  0.03%  34.6    1s
# *  761   119              53       0.6864483    0.68659  0.02%  34.0    1s
#
# Cutting planes:
#   RLT: 2
#
# Explored 1017 nodes (28384 simplex iterations) in 2.01 seconds (0.66 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 0.686448 0.686448 0.686448 ... 0.686404
#
# Optimal solution found (tolerance 1.00e-04)
# Warning: max constraint violation (1.3124e-06) exceeds tolerance
# Best objective 6.864482501804e-01, best bound 6.864679385886e-01, gap 0.0029%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0xfe9860e8
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 8e+01]
#   QMatrix range    [1e+00, 6e+01]
#   QLMatrix range   [1e+00, 6e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 4e+01]
#   QRHS range       [1e+01, 3e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.01s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.6713354
#
# Root relaxation: objective 6.898798e-01, 566 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.68988    0   11    0.67134    0.68988  2.76%     -    0s
#      0     0    0.68879    0   12    0.67134    0.68879  2.60%     -    0s
#      0     0    0.68839    0   12    0.67134    0.68839  2.54%     -    0s
#      0     2    0.68839    0   12    0.67134    0.68839  2.54%     -    0s
#
# Explored 21 nodes (1416 simplex iterations) in 0.31 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 0.671335
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.713353903179e-01, best bound 6.713398064123e-01, gap 0.0007%
# Set parameter DualReductions to value 0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (mac64[arm] - Darwin 24.5.0 24F74)
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Academic license 2579375 - for non-commercial use only - registered to ma___@iitd.ac.in
# Optimize a model with 5 rows, 552 columns and 603 nonzeros
# Model fingerprint: 0x7f1ab556
# Model has 6 quadratic constraints
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+01]
#   QMatrix range    [1e+00, 7e+01]
#   QLMatrix range   [1e+00, 7e+01]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [6e-01, 1e+00]
#   RHS range        [1e+00, 8e+00]
#   QRHS range       [2e+00, 2e+01]
#
# Continuous model is non-convex -- solving as a MIP
#
# Presolve time: 0.00s
# Presolved: 1223 rows, 1158 columns, 4690 nonzeros
# Presolved model has 606 bilinear constraint(s)
# Variable types: 1158 continuous, 0 integer (0 binary)
# Found heuristic solution: objective 0.8082481
#
# Root relaxation: objective 8.268795e-01, 526 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.82688    0   19    0.80825    0.82688  2.31%     -    0s
# H    0     0                       0.8082483    0.82688  2.31%     -    0s
#      0     0    0.82647    0   17    0.80825    0.82647  2.25%     -    0s
#      0     0    0.82644    0   19    0.80825    0.82644  2.25%     -    0s
#      0     2    0.82644    0   19    0.80825    0.82644  2.25%     -    0s

# %%
# 6 min 6 sec for 2
